# %% [markdown]
# # Fundamentos em Ciências de Dados
#
# ## Profa. Cibele Russo
#
#
# ### Aula 2: O método científico
# #### Conteúdo da Aula
#
# - O método científico: Métodos, Técnicas e Algoritmos
#
#
# Fonte:
#
# - Moreira, João, André Carlos Ponce de Leon Ferreira, and Tomáš Horváth. A general introduction to data analytics. Wiley, 2019.

# %% [markdown]
# ## O método científico: Métodos, Técnicas e Algoritmos
#
# Antes de começarmos a programar ou aplicar modelos em ciência de dados, é importante compreender alguns conceitos fundamentais que aparecem com frequência na literatura e na prática: **métodos**, **técnicas** e **algoritmos**.
#
# Embora esses termos sejam frequentemente utilizados como sinônimos no dia a dia, eles possuem significados distintos.
#
#
# Existe uma distinção clara entre esses termos, embora eles estejam intimamente relacionados no contexto da análise de dados e programação:
#
# -   **Método ou Técnica:** É definido como um **procedimento sistemático** que permite alcançar um objetivo pretendido. O método descreve, de forma geral, como realizar uma determinada tarefa. Por exemplo, o cálculo da média de idades de um grupo é um método.
#
# -   **Algoritmo:** É um conjunto de **instruções passo a passo**, auto-contido e facilmente compreensível por humanos, que permite a **implementação** de um determinado método. Os algoritmos são projetados para serem facilmente traduzidos para qualquer linguagem de programação.
#
# ### Relação entre eles
# A principal diferença é que o método mostra o "que" fazer e o caminho sistemático, enquanto o **algoritmo fornece as instruções detalhadas** para que esse método seja executado por um computador.
#
# **Exemplo Prático:**
#
# -  **Método:** Obter a média aritmética de uma lista de números.
#
# - **Algoritmo**
#
#     1. **Iniciar** uma variável chamada `soma` com valor igual a **0**.
#     2. **Calcular** o número de elementos da lista e armazenar em uma variável `n`.
#     3. **Percorrer** todos os elementos da lista.
#         3.1. **Adicionar** cada elemento da lista à variável `soma`.
#     4. **Dividir** o valor total da `soma` pelo número de elementos `n`.
#     5. **Retornar** o resultado da divisão como a média da lista.

# %% [markdown]
# Exercício: Adaptar método e algoritmo acima para calcular média ponderada de notas de um aluno no 1. semestre do BCDados.

# %%
def media(numeros):
  soma = 0

  n = len(numeros)

  for numero in numeros:
      soma += numero

  media = soma / n

  return media

inteiros_aleatorios = [4, 5, 8, 9]

media(inteiros_aleatorios)

def media_ponderada(dicionario, chave_notas, chave_alunos):
  soma_ponderada = 0

  for i in range(len(dicionario[chave_notas])):
    soma_ponderada += dicionario[chave_notas][i]

  media = soma_ponderada / len(dicionario[chave_alunos])

  return media

nota_alunos = {'nota':[7, 8, 9, 10], 'aluno': ['alfredo', 'felipe', 'joao', 'maria']}

media_ponderada(nota_alunos, 'nota', 'aluno')
# Out:
# 8.5

# %% [markdown]
# Como em Moreira e outros (2019):
# O algoritmo apresentado na **página 10** das fontes descreve o processo para calcular a **idade média** de uma lista de contatos.
#
#
# ### Algoritmo: Calcular a idade média dos nossos contatos
#
# **1: ENTRADA:** $A$: um vetor de tamanho $N$ com as idades de todos os contatos.
# **2:** $S \leftarrow 0$ $\quad \triangleright$ *Inicializa a soma $S$ em zero*
# **3: para** $i = 1$ **até** $N$ **faça** $\quad \triangleright$ *Itera por todos os elementos de $A$*
# **4:** $\quad S \leftarrow S + A_i$ $\quad \triangleright$ *Adiciona o elemento atual ($i$-ésimo) de $A$ a $S$*
# **5:** $M \leftarrow S / N$ $\quad \triangleright$ *Divide a soma pelo número $N$ de contatos*
# **6: retorne($M$)** $\quad \triangleright$ *Retorna o resultado, ou seja, a idade média dos $N$ contatos*.

# %% [markdown]
# Em ciência de dados, técnicas como o **k-médias** são aplicadas através de algoritmos específicos que seguem passos repetitivos (como associar instâncias a centroides e recalcular esses centroides) até que o objetivo do método seja atingido.
#
# Além disso, as fontes destacam que a **lógica de programação** (essencial para criar algoritmos) é considerada mais importante do que qualquer linguagem de programação específica, pois uma vez aprendida, ela permite ao programador resolver problemas em diversas linguagens.

# %% [markdown]
# ## Método e Algoritmo: Exemplo da Pipoca 🍿
#
# Um exemplo simples para entender a diferença entre **método** e **algoritmo** é o problema de **estourar pipoca**.
#
# Um mesmo problema pode ser resolvido por **diferentes métodos**, e cada método pode ser descrito por **um algoritmo específico**, ou seja, por uma sequência detalhada de passos.
#
#
#
# ### Problema
#
# **Estourar pipoca.**
#
#
#
# ### Métodos possíveis
#
# **Método 1: aquecimento no fogão (panela)**
# Utiliza uma panela e uma fonte de calor do fogão para aquecer os grãos de milho.
#
# **Método 2: aquecimento no micro-ondas**
# Utiliza radiação de micro-ondas para aquecer os grãos até que estourem.
#
#
#
# ### O que é um método?
#
# Um **método** é um **procedimento geral** utilizado para alcançar um objetivo.
# Ele descreve **a ideia ou estratégia de solução**, mas não necessariamente todos os detalhes da execução.
#
# **Exemplo de método para estourar pipoca**
#
# > Aquecer os grãos de milho até que atinjam a temperatura necessária para estourar, utilizando uma fonte de calor adequada e evitando que queimem.
#
# Observe que o método descreve **a estratégia geral**, mas não especifica exatamente **quais passos devem ser seguidos**.
#
#
#
# ### Algoritmo
#
# Um **algoritmo** é um **conjunto finito de instruções passo a passo** que descreve exatamente **como executar uma tarefa**.
#
# **Exemplo: algoritmo para estourar pipoca (no fogão)**
#
# 1. Pegue uma panela com tampa.
# 2. Coloque a panela no fogão.
# 3. Adicione **2 colheres de sopa de óleo**.
# 4. Ligue o fogo em temperatura média.
# 5. Adicione **1/2 xícara de milho de pipoca**.
# 6. Tampe a panela.
# 7. Aguarde os primeiros estouros.
# 8. Mexa a panela levemente de tempos em tempos para evitar que a pipoca queime.
# 9. Quando o intervalo entre os estouros for maior que **2 ou 3 segundos**, desligue o fogo.
# 10. Abra a tampa com cuidado.
# 11. Coloque a pipoca em um recipiente.
# 12. Adicione sal ou tempero a gosto.
#
#
#
# ### Resumindo
#
# | Conceito | Descrição |
# |--------|--------|
# | **Método** | Estratégia geral para resolver um problema |
# | **Algoritmo** | Passo a passo detalhado para executar a solução |
#
# No exemplo:
#
# - **Método:** aquecer o milho até ele estourar.
#
# - **Algoritmo:** sequência detalhada de passos para produzir a pipoca.

# %% [markdown]
# ## Pensamento Científico na Ciência de Dados
#
#
# Com base nas fontes fornecidas, o **método científico** aplicado à análise de dados é fundamentado na **estatística**, especificamente na **aprendizagem indutiva**, que busca generalizar conhecimento a partir de amostras.
#
#
#
# Os principais componentes do **pensamento científico** na ciência de dados:
#
# - **Indução (Inferência Estatística):** processo de generalizar conhecimento a partir de uma **amostra** para inferir padrões ou estimativas para a **população**. Em ciência de dados, ocorre quando modelos aprendem padrões a partir de dados históricos.
#
# - **Dedução:** processo inverso da indução. Parte de um **modelo ou conhecimento geral** para **prever ou classificar casos específicos**.
#
# - **Analytics (Extração de Padrões):** uso de métodos analíticos para **organizar, transformar e interpretar dados**, extraindo conhecimento útil a partir de dados brutos.
#
# > **Analytics** é definida como a ciência que analisa dados brutos para extrair conhecimento útil (padrões).
#
# - **Gestão de Incerteza e Ruído:** reconhecimento de que dados reais possuem **imprecisões**, exigindo equilíbrio entre **viés** (modelo muito simples) e **variância** (modelo muito sensível aos dados).
#
# - **Validação e Generalização:** verificação de que o modelo **não apenas memoriza os dados**, mas **generaliza bem para novos dados**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Indução e Dedução
#
# *   **Indução (Inferência Estatística):** É o processo de generalizar o conhecimento obtido de uma amostra para toda a população. Como as populações costumam ser muito grandes ou proibitivamente caras para serem totalmente pesquisadas, a ciência utiliza a amostragem para estimar valores populacionais.
#
#
# *   **Dedução:** É o inverso da indução; ela particulariza da população para a amostra. As probabilidades, por exemplo, tratam de problemas dedutivos ao tentar prever a natureza de uma amostra sabendo-se as características da população.

# %% [markdown]
# ![Captura de tela de 2026-03-12 11-06-31.png](data:image/png;base64,...)
#
# Fonte: Moreira e outros (2019)

# %% [markdown]
# ### Metodologias Estruturadas
# O método científico em dados não é aleatório; ele segue frameworks rigorosos para garantir a validade do conhecimento descoberto:
#
# *   **Processo KDD (Knowledge Discovery from Data):** Uma metodologia acadêmica que propõe nove etapas sequenciais, embora permita retroceder passos para refinar o processo. As etapas incluem
#
#     1. Aprender o domínio da aplicação: Entender os objetivos e as características do problema
#
#     2. Criar um conjunto de dados alvo: Identificar quais dados e atributos são necessários e como serão coletados
#
#     3. Limpeza e pré-processamento de dados: Lidar com valores ausentes, ruídos e definir tipos de dados
#
#     4. Redução e projeção de dados: Selecionar características relevantes e remover atributos irrelevantes
#
#     5. Escolher a função de mineração de dados: Decidir o tipo de método (ex: sumarização, agrupamento, classificação ou regressão)
#
#     6. Escolher o(s) algoritmo(s) de mineração de dados: Selecionar os métodos específicos que se ajustam aos dados
#
#     7. Mineração de dados: Aplicar os algoritmos para extrair padrões e ajustar parâmetros
#
#     8. Interpretação: Avaliar a utilidade e o significado dos resultados para o usuário final
#
#     9. Uso do conhecimento descoberto: Integrar o novo conhecimento no sistema operacional ou em relatórios

# %% [markdown]
# *   **CRISP-DM: (CRoss-Industry Standard Process for Data Mining)** Uma metodologia voltada para a indústria que organiza o projeto em seis fases cíclicas:
#
#     1. Compreensão do negócio (Business understanding): Definir o problema sob a perspectiva do negócio e traduzi-lo para um problema de análise de dados
#
#     2. Compreensão dos dados (Data understanding): Coletar dados iniciais e realizar uma análise exploratória para obter os primeiros insights e verificar a qualidade
#
#     3. Preparação dos dados (Data preparation): Selecionar, limpar e transformar os dados para que possam ser inseridos nas ferramentas de modelagem
#
#     4. Modelagem (Modeling): Selecionar e aplicar técnicas de análise, ajustando os hiperparâmetros necessários
#
#     5. Avaliação (Evaluation): Verificar se a solução obtida atende aos requisitos e objetivos do negócio definidos inicialmente
#
#     6. Implantação (Deployment): Integrar a solução de análise nos processos de negócio da empresa

# %% [markdown]
# ![Captura de tela de 2026-03-11 21-40-49.png](data:image/png;base64,...)
#
# Fonte: Moreira e outros (2019)

# %% [markdown]
# ![CRISP-DM.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Métodos e Algoritmos
#
# A ciência de dados distingue o conceito abstrato da execução técnica:
#
# *   **Método (ou Técnica):** É um procedimento sistemático para atingir um objetivo pretendido.
#
# *   **Algoritmo:** É um conjunto de instruções passo a passo, autocontido e compreensível, que permite a implementação de um método. Um algoritmo descreve, por exemplo, como calcular matematicamente a média de uma amostra ou como induzir um modelo de previsão.

# %% [markdown]
# ### Modelagem e Generalização
#
# O objetivo final do método científico em dados é a **indução de modelos**.
#
# Um modelo é uma generalização que pode ser usada como protótipo para gerar previsões sobre novos objetos desconhecidos.
#
# A ciência busca minimizar erros de previsão futuros através do treinamento e validação desses modelos em conjuntos de dados distintos.
#
# Em resumo, a abordagem científica na programação e análise de dados exige **lógica**, **paciência** e **atenção aos detalhes**, pois a lógica de programação é considerada mais importante do que qualquer linguagem específica para expressar soluções científicas.

# %% [markdown]
# ## Aplicando o método científico na análise de dados
#
# Uma forma comum de aplicar o método científico em ciência de dados é usar metodologias estruturadas.
# Uma das mais conhecidas é a **CRISP-DM (Cross Industry Standard Process for Data Mining)**.
#
# Para ilustrar esse processo, vamos usar um exemplo clássico: o **conjunto de dados de câncer de mama de Wisconsin**.
#
#
#
# ### 1. Compreensão do problema
#
# O primeiro passo é definir o problema.
#
# Imagine que um hospital deseja um **sistema de apoio ao diagnóstico de câncer de mama**.
#
# A pergunta central é:
#
# > Existem padrões nas características das células que permitam diferenciar tumores benignos de malignos?
#
# Essa etapa define o objetivo da análise.
#
#
#
# ### 2. Compreensão dos dados
#
# Em seguida, analisamos os dados disponíveis.
#
# No dataset de Wisconsin, os dados vêm de **imagens digitalizadas de biópsias por aspiração com agulha fina**.
#
# Cada observação descreve características das células, como:
#
# - espessura do aglomerado celular
# - uniformidade do tamanho das células
# - uniformidade da forma das células
# - presença de núcleos nus
#
# Também verificamos a qualidade dos dados.
# Por exemplo, o atributo **"núcleos nus" possui valores ausentes**.
#
#
#
# ### 3. Preparação dos dados
#
# Antes da modelagem, os dados precisam ser preparados.
#
# As principais etapas incluem:
#
# - **Limpeza:** remover registros com valores ausentes
# - **Seleção:** excluir variáveis que não ajudam na análise (ex.: ID da amostra)
# - **Escala:** verificar se as variáveis precisam ser normalizadas
#
# Neste dataset, as variáveis já estão na escala **1 a 10**, então não foi necessário normalizar.
#
#
#
# ### 4. Modelagem
#
# Agora aplicamos técnicas para identificar padrões.
#
# No exemplo, utiliza-se o **k-médias**, um algoritmo de **agrupamento (clustering)**.
#
# O pesquisador testa diferentes valores de \(k\), que representa o número de grupos.
#
# O objetivo é encontrar padrões estáveis nos dados.
#
#
#
# ### 5. Avaliação
#
# Nesta etapa verificamos se os resultados fazem sentido.
#
# Uma ferramenta comum é a **curva do cotovelo (elbow curve)**, usada para escolher o número de grupos.
#
# No exemplo, **quatro grupos** descrevem bem os padrões observados.
#
# Também se observa que:
#
# - tumores benignos tendem a ser mais homogêneos
# - tumores malignos apresentam maior variabilidade
#
#
#
# ### 6. Implantação
#
# Por fim, o modelo pode ser usado na prática.
#
# Ele pode integrar um **sistema de apoio ao diagnóstico médico**.
#
# Assim, novas amostras podem ser analisadas automaticamente.
#
#
#
# ### Resumo das etapas da CRISP-DM
#
# 1. Compreensão do problema
# 2. Compreensão dos dados
# 3. Preparação dos dados
# 4. Modelagem
# 5. Avaliação
# 6. Implantação

# %% [markdown]
# ![Gemini_Generated_Image_6quhv26quhv26quh (1).png](data:image/png;base64,...)

# %% [markdown]
# Conjunto de dados de câncer de mama Winsconsin
#
# | Variável | Descrição |
# |---|---|
# | diagnostico | Diagnóstico do tumor (0 = maligno, 1 = benigno) |
# | mean radius | Média da distância do centro ao perímetro da célula |
# | mean texture | Variabilidade na intensidade de cinza da imagem |
# | mean perimeter | Perímetro médio da célula |
# | mean area | Área média da célula |
# | mean smoothness | Variação local no comprimento do raio |
# | mean compactness | Medida de compacidade da forma |
# | mean concavity | Grau de concavidade do contorno |
# | mean concave points | Número de pontos côncavos no contorno |
# | mean symmetry | Medida de simetria da célula |
# | mean fractal dimension | Complexidade do contorno celular |
# | radius error | Erro padrão do raio |
# | texture error | Erro padrão da textura |
# | perimeter error | Erro padrão do perímetro |
# | area error | Erro padrão da área |
# | smoothness error | Erro padrão da suavidade |
# | compactness error | Erro padrão da compacidade |
# | concavity error | Erro padrão da concavidade |
# | concave points error | Erro padrão dos pontos côncavos |
# | symmetry error | Erro padrão da simetria |
# | fractal dimension error | Erro padrão da dimensão fractal |
# | worst radius | Maior raio observado |
# | worst texture | Maior textura observada |
# | worst perimeter | Maior perímetro observado |
# | worst area | Maior área observada |
# | worst smoothness | Maior suavidade observada |
# | worst compactness | Maior compacidade observada |
# | worst concavity | Maior concavidade observada |
# | worst concave points | Maior número de pontos côncavos |
# | worst symmetry | Maior simetria observada |
# | worst fractal dimension | Maior dimensão fractal observada |

# %%
# Leitura e exploração inicial do conjunto de dados de Câncer de Mama de Wisconsin

import pandas as pd
from sklearn.datasets import load_breast_cancer

# carregando o dataset
dados = load_breast_cancer()

# criando um DataFrame
df = pd.DataFrame(dados.data, columns=dados.feature_names)

# adicionando a variável resposta (diagnóstico)
df["diagnostico"] = dados.target

# %%
df.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'diagnostico'],
#       dtype='object')

# %%
# primeiras linhas do conjunto de dados
print("Primeiras observações:")
print(df.head())
# Out:
# Primeiras observações:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
# ...

# %%
# dimensão do dataset
print("\nDimensão dos dados (linhas, colunas):")
print(df.shape)
# Out:
# Dimensão dos dados (linhas, colunas):
# (569, 31)

# %%
# resumo estatístico
print("\nResumo estatístico:")
print(df.describe())
# Out:
# Resumo estatístico:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# ...

# %%
# contagem das classes
print("\nDistribuição dos diagnósticos:")
print(df["diagnostico"].value_counts())
# Out:
# Distribuição dos diagnósticos:
# diagnostico
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
# observação sobre as classes
print("\nLegenda:")
print("0 = tumor maligno")
print("1 = tumor benigno")
# Out:
# Legenda:
# 0 = tumor maligno
# 1 = tumor benigno
